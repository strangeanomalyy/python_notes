# %%
import pandas as pd

# %% [markdown]
# - <b>Multi-index</b> : (multi dimensional data)

# %%
df = pd.read_csv("bigmac.csv", parse_dates = ["Date"]) 
# parse_dates converts the column to a datetime object
df.head()
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35
# 3 2016-01-01    Britain                 4.22
# 4 2016-01-01     Canada                 4.14

# %%
df.info() # no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# ## Create a Multi-Index with the `.set_index()` Method

# %%
df = pd.read_csv("bigmac.csv")
df["Date"] = pd.to_datetime(df["Date"]) 
# an alternative method to convert the column to datetime
df.head()
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35
# 3 2016-01-01    Britain                 4.22
# 4 2016-01-01     Canada                 4.14

# %%
df.nunique()
# date has the least number of unique values
# Out:
# Date                    12
# Country                 58
# Price in US Dollars    330
# dtype: int64

# %%
df.set_index(["Date","Country"], inplace = True)
# df.set_index(["Country", "Date"])
# multi-level index (two levels)
# the order of the list is important
# best practice (least unique number is in the outer level)
df
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
df.sort_index(inplace = True)
# sorts the first index (dates), then second index (country), and so on...
# similar to .sort_values()
df
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
df.index
# 2 indexes = tuple of 2 values
# 3 indexes = tuple of 3 values
# tuple = stores multiple items in a single variable

df.index.names
# immutable list
# index name is based on the column name in the dataframe
# they are also given an index position too (index within an index)
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(df.index)

df.index[10]
# tuple
# type(df.index[10]) # to check
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Denmark')

# %% [markdown]
# ## Extract Index Level Values with the `.get_level_values` Method

# %%
df = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
df.sort_index(inplace = True)
df.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
df.index.get_level_values("Date") # can use name of column 
df.index.get_level_values(0) # or use the index position
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
df.index.get_level_values("Country")
df.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# ## Change Index Level Name with the `.set_names` Method

# %%
df = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date","Country"])
df.sort_index(inplace = True)
df.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
df.index.set_names(names = ["Day","Location"], inplace = True) # changes the name of the index
df.head(3)
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
df.index.set_names("Date",level = 0) 
df.index.set_names("Date", level = "Day", inplace = True)
# level of the multi index 
df.head(3)
# Out:
#                       Price in US Dollars
# Date       Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %% [markdown]
# ## The `.sort_index()` Method on a `Multi-Index` `Data Frame`

# %%
df = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date","Country"])
df.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
df.sort_index()
df.sort_index(ascending = True) # default
df.sort_index(ascending = False)
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                       2.67
#            Venezuela                     0.66
#            Uruguay                       3.74
#            United States                 4.93
#            Ukraine                       1.54
# ...                                       ...
# 2010-01-01 Canada                        3.97
#            Britain                       3.67
#            Brazil                        4.76
#            Australia                     3.98
#            Argentina                     1.84
#
# [652 rows x 1 columns]

# %%
# customizing the order of arrangement
df.sort_index(ascending = [True,False])
df.sort_index(ascending = [False,True], inplace = True)

# %%
df.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Austria                   3.76
#            Belgium                   4.25
#            Brazil                    3.35

# %%
df.sort_index(level = 0)
df.sort_index(level = "Date")
df.sort_index(level = 1)
df.sort_index(level = "Country")
df.sort_index(level = "Country", ascending = False)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                   2.67
# 2015-07-01 Vietnam                   2.75
# 2015-01-01 Vietnam                   2.81
# 2014-07-01 Vietnam                   2.83
# 2014-01-01 Vietnam                   2.84
# ...                                   ...
# 2012-07-01 Argentina                 4.16
# 2012-01-01 Argentina                 4.64
# 2011-07-01 Argentina                 4.84
# 2010-07-01 Argentina                 3.56
# 2010-01-01 Argentina                 1.84
#
# [652 rows x 1 columns]

# %% [markdown]
# ## Extract Rows from a `Multi-Index` `DataFrame`

# %%
df = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date","Country"])
df.sort_index(inplace = True)
df.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
# this method is ambiguous and could confuse whoever will read your code
df.loc['2010-01-01','Argentina']
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
df.loc['2010-01-01','Price in US Dollars']
# Out:
# Date        Country
# 2010-01-01  Argentina         1.84
#             Australia         3.98
#             Brazil            4.76
#             Britain           3.67
#             Canada            3.97
#             Chile             3.18
#             China             1.83
#             Colombia          3.91
#             Costa Rica        3.52
#             Czech Republic    3.71
#             Denmark           5.99
#             Egypt             2.38
#             Euro area         4.84
#             Hong Kong         1.91
#             Hungary           3.86
#             Indonesia         2.24
#             Israel            3.99
#             Japan             3.50
#             Latvia            3.09
#             Lithuania         2.87
#             Malaysia          2.08
#             Mexico            2.50
#             New Zealand       3.61
#             Norway            7.02
#             Pakistan          2.42
#             Peru              2.81
# ...

# %%
df.loc[('2010-01-01', 'Argentina'),'Price in US Dollars'] #Tuple
# Out:
# Date        Country
# 2010-01-01  Argentina    1.84
# Name: Price in US Dollars, dtype: float64

# %%
df.loc[('2010-01-01','Argentina'),('Price in US Dollars','Price in US Dollars')]
# Out:
#                       Price in US Dollars  Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84                 1.84

# %%
df.loc[('2010-01-01')]
# compare the difference
df.loc[('2010-01-01',)]
# Out:
#                 Price in US Dollars
# Country
# Argentina                      1.84
# Australia                      3.98
# Brazil                         4.76
# Britain                        3.67
# Canada                         3.97
# Chile                          3.18
# China                          1.83
# Colombia                       3.91
# Costa Rica                     3.52
# Czech Republic                 3.71
# Denmark                        5.99
# Egypt                          2.38
# Euro area                      4.84
# Hong Kong                      1.91
# Hungary                        3.86
# Indonesia                      2.24
# Israel                         3.99
# Japan                          3.50
# Latvia                         3.09
# Lithuania                      2.87
# Malaysia                       2.08
# Mexico                         2.50
# New Zealand                    3.61
# Norway                         7.02
# Pakistan                       2.42
# ...

# %%
#index position counts from outside in 
df.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
df.iloc[0]
df.iloc[10]
df.iloc[[10,20,30]]
df.iloc[[10,20,30,250]]
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Denmark                   5.99
#            Malaysia                  2.08
#            Singapore                 3.19
# 2012-07-01 Turkey                    4.52

# %% [markdown]
# ## The `.transpose()` Method

# %%
df = pd.read_csv('bigmac.csv',parse_dates = ['Date'], index_col = ['Date','Country'])
df.sort_index(inplace = True)
df.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
df = df.transpose()
df.head(3)
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
df.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')] # pulling two indexes
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83

# %% [markdown]
# ## The `.swaplevel()` Method

# %%
df = pd.read_csv('bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
df.sort_index(inplace = True)
df.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
df.swaplevel() # switches the index positions
#df.swaplevel('Country', 'Date')
df.swaplevel(0,1)
#df.swaplevel(1,0)
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
df = df.swaplevel(1,0)

# %%
df.head(3)
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2010-01-01                 1.84
# Australia 2010-01-01                 3.98
# Brazil    2010-01-01                 4.76

# %% [markdown]
# ## The `.stack()` Method

# %%
df = pd.read_csv('worldstats.csv', index_col = ['country','year'])
df.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
type(df.stack()) # turns the rest of the columns into a column and "stacking them" per multiindex
# converted data frame to a pandas series
# Out:
# pandas.core.series.Series

# %%
df.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %% [markdown]
# ## The `.unstack()` Method

# %%
df = pd.read_csv('worldstats.csv',index_col = ['country','year'])
df.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
s = df.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack().unstack().unstack()
# Out:
#             year  country
# Population  1960  Afghanistan           8.994793e+06
#                   Albania                        NaN
#                   Algeria               1.112489e+07
#                   Andorra                        NaN
#                   Angola                         NaN
#                                             ...
# GDP         2015  West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Yemen, Rep.                    NaN
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 28224, dtype: float64

# %%
s.unstack(2).unstack(0)
# selecting which index position you want to unstack
s.unstack(-1).unstack(-1)
# Out:
#                       Population                                            \
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %%
s.unstack('country')
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %%
df = pd.read_csv('worldstats.csv',index_col = ['country','year'])
s = df.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(level = [0,1])
s.unstack(level = ['country','year'])
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s = s.unstack('year', fill_value = 0)
s.head()
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
# ...

# %% [markdown]
# ## The `.pivot()` Method

# %%
df = pd.read_csv('salesmen.csv', parse_dates = ['Date'])
df['Salesman'] = df['Salesman'].astype('category')
len(df)
# Out:
# 1830

# %%
s = df.pivot(index = 'Date', columns = 'Salesman', values = 'Revenue')
len(s)
# Out:
# 366

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1830 non-null   datetime64[ns]
#  1   Salesman  1830 non-null   category
#  2   Revenue   1830 non-null   int64
# dtypes: category(1), datetime64[ns](1), int64(1)
# memory usage: 30.7 KB

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2016-01-01 to 2016-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Bob     366 non-null    int64
#  1   Dave    366 non-null    int64
#  2   Jeb     366 non-null    int64
#  3   Oscar   366 non-null    int64
#  4   Ronald  366 non-null    int64
# dtypes: int64(5)
# memory usage: 17.2 KB

# %% [markdown]
# ## The `.pivot_table()` Method

# %% [markdown]
# * like the 'summary' in jmp

# %%
df = pd.read_csv('foods.csv')
df
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
df.pivot_table(values = 'Spend', index = 'Gender', aggfunc = 'mean')
df.pivot_table(values = 'Spend', index = 'Gender', aggfunc = 'sum')
df.pivot_table(values = 'Spend', index = 'Item', aggfunc = 'sum')
df.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = 'City', aggfunc = ['count','sum','std'])
# Out:
#                     count                            sum               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger          24           31       27  1239.04      1639.24
#        Burrito         23           28       34   978.95      1458.76
#        Chalupa         19           32       25   876.58      1673.33
#        Donut           31           30       34  1446.78      1639.26
#        Ice Cream       27           32       22  1521.62      1479.22
#        Sushi           31           30       32  1480.29      1742.88
# Male   Burger          22           21       31  1294.09       938.18
#        Burrito         25           30       28  1399.40      1312.93
#        Chalupa         25           23       23  1227.77      1114.23
#        Donut           30           33       29  1345.27      1249.36
#        Ice Cream       29           41       25  1603.63      2191.27
# ...

# %%
pd.pivot_table(data = df, values = 'Spend', index = ['Gender','Item'], columns = 'City', aggfunc = 'sum')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %% [markdown]
# ## The `pd.melt()` Method

# %%
# unpivots table 
pd.melt()

# %%
df = pd.read_csv('quarters.csv')
df
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
s = pd.melt(df, id_vars = 'Salesman', var_name = 'Quarter', value_name = 'Revenue')
s.set_index(['Quarter', 'Salesman'])
# Out:
#                   Revenue
# Quarter Salesman
# Q1      Boris      602908
#         Bob         43790
#         Tommy      392668
#         Travis     834663
#         Donald     580935
#         Ted        656644
#         Jeb        486141
#         Stacy      479662
#         Morgan     992673
# Q2      Boris      233879
#         Bob        514863
#         Tommy      113579
#         Travis     266785
#         Donald     411379
#         Ted         70803
#         Jeb        600753
#         Stacy      742806
#         Morgan     879183
# Q3      Boris      354479
#         Bob        297151
#         Tommy      430882
#         Travis     749238
#         Donald     110390
#         Ted        375948
#         Jeb        742716
#         Stacy      770712
#         Morgan      37945
# Q4      Boris       32704
#         Bob        544493
#         Tommy      247231
#         Travis     570524
#         Donald     651572
#         Ted        321388
#         Jeb        404995
# ...
